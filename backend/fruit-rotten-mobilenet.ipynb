# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

# %%
# Image and training settings
img_height, img_width = 224, 224
batch_size = 32
epochs = 20

# %%
# Path to dataset
data_dir = "/kaggle/input/fruit-and-vegetable-disease-healthy-vs-rotten/Fruit And Vegetable Diseases Dataset"

# %%
# Ensure GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("✅ GPU ready!")
    except RuntimeError as e:
        print("⚠️", e)
# Out:
# ✅ GPU ready!

# %%
# Image data generators
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_gen = datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_gen = datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 23431 images belonging to 28 classes.
# Found 5846 images belonging to 28 classes.

# %%
# Class weights to handle imbalance
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_gen.classes),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights))

# %%
# Base model: MobileNetV2
base_model = MobileNetV2(include_top=False, weights='imagenet', input_shape=(img_height, img_width, 3))
base_model.trainable = False  # Freeze base initially
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Custom top layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
output = Dense(train_gen.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
# Compile initial (frozen) model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=5,
    class_weight=class_weights
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  88/733 ━━━━━━━━━━━━━━━━━━━━ 8:24 781ms/step - accuracy: 0.2889 - loss: 2.9021
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 777s 1s/step - accuracy: 0.6592 - loss: 1.2762 - val_accuracy: 0.8874 - val_loss: 0.4021
# Epoch 2/5
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 505s 684ms/step - accuracy: 0.9006 - loss: 0.2929 - val_accuracy: 0.8970 - val_loss: 0.3795
# Epoch 3/5
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 516s 699ms/step - accuracy: 0.9210 - loss: 0.2224 - val_accuracy: 0.9066 - val_loss: 0.3369
# Epoch 4/5
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 508s 688ms/step - accuracy: 0.9345 - loss: 0.1871 - val_accuracy: 0.9042 - val_loss: 0.3784
# Epoch 5/5
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 468s 634ms/step - accuracy: 0.9379 - loss: 0.1717 - val_accuracy: 0.9059 - val_loss: 0.3598

# %%
# 🔓 Unfreeze top layers of MobileNetV2 for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:100]:  # Freeze first 100 layers
    layer.trainable = False

# %%
# Re-compile with a lower learning rate for fine-tuning
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.2, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fine-tuning
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    class_weight=class_weights,
    callbacks=[lr_scheduler, early_stop]
)
# Out:
# Epoch 1/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 507s 663ms/step - accuracy: 0.8639 - loss: 0.4242 - val_accuracy: 0.8418 - val_loss: 0.6527 - learning_rate: 1.0000e-04
# Epoch 2/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 475s 644ms/step - accuracy: 0.9535 - loss: 0.1302 - val_accuracy: 0.9051 - val_loss: 0.3585 - learning_rate: 1.0000e-04
# Epoch 3/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 482s 653ms/step - accuracy: 0.9647 - loss: 0.1168 - val_accuracy: 0.9078 - val_loss: 0.3905 - learning_rate: 1.0000e-04
# Epoch 4/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 491s 666ms/step - accuracy: 0.9722 - loss: 0.0814 - val_accuracy: 0.9263 - val_loss: 0.3216 - learning_rate: 1.0000e-04
# Epoch 5/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 471s 638ms/step - accuracy: 0.9776 - loss: 0.0657 - val_accuracy: 0.9261 - val_loss: 0.3356 - learning_rate: 1.0000e-04
# Epoch 6/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 467s 632ms/step - accuracy: 0.9820 - loss: 0.0481 - val_accuracy: 0.9499 - val_loss: 0.2052 - learning_rate: 1.0000e-04
# Epoch 7/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 467s 632ms/step - accuracy: 0.9806 - loss: 0.0559 - val_accuracy: 0.9384 - val_loss: 0.2480 - learning_rate: 1.0000e-04
# Epoch 8/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 468s 634ms/step - accuracy: 0.9841 - loss: 0.0497 - val_accuracy: 0.8647 - val_loss: 0.6327 - learning_rate: 1.0000e-04
# Epoch 9/20
# 732/733 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.9865 - loss: 0.0443
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 465s 629ms/step - accuracy: 0.9865 - loss: 0.0443 - val_accuracy: 0.9314 - val_loss: 0.3191 - learning_rate: 1.0000e-04
# Epoch 10/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 468s 635ms/step - accuracy: 0.9897 - loss: 0.0302 - val_accuracy: 0.9540 - val_loss: 0.1753 - learning_rate: 2.0000e-05
# Epoch 11/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 471s 639ms/step - accuracy: 0.9929 - loss: 0.0172 - val_accuracy: 0.9524 - val_loss: 0.2013 - learning_rate: 2.0000e-05
# Epoch 12/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 482s 653ms/step - accuracy: 0.9934 - loss: 0.0162 - val_accuracy: 0.9595 - val_loss: 0.1736 - learning_rate: 2.0000e-05
# Epoch 13/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 476s 645ms/step - accuracy: 0.9946 - loss: 0.0120 - val_accuracy: 0.9589 - val_loss: 0.1722 - learning_rate: 2.0000e-05
# Epoch 14/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 466s 631ms/step - accuracy: 0.9953 - loss: 0.0113 - val_accuracy: 0.9581 - val_loss: 0.1736 - learning_rate: 2.0000e-05
# Epoch 15/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 467s 632ms/step - accuracy: 0.9973 - loss: 0.0078 - val_accuracy: 0.9610 - val_loss: 0.1769 - learning_rate: 2.0000e-05
# Epoch 16/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.9956 - loss: 0.0077
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 473s 641ms/step - accuracy: 0.9956 - loss: 0.0077 - val_accuracy: 0.9593 - val_loss: 0.1824 - learning_rate: 2.0000e-05
# Epoch 17/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 470s 637ms/step - accuracy: 0.9968 - loss: 0.0064 - val_accuracy: 0.9600 - val_loss: 0.1849 - learning_rate: 4.0000e-06
# Epoch 18/20
# 733/733 ━━━━━━━━━━━━━━━━━━━━ 469s 635ms/step - accuracy: 0.9972 - loss: 0.0066 - val_accuracy: 0.9603 - val_loss: 0.1893 - learning_rate: 4.0000e-06

# %%
# Final evaluation
loss, accuracy = model.evaluate(val_gen)
print(f"\n✅ Final Fine-Tuned Accuracy: {accuracy*100:.2f}% | Loss: {loss:.4f}")
# Out:
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 93s 505ms/step - accuracy: 0.8983 - loss: 0.4308
#
# ✅ Final Fine-Tuned Accuracy: 95.93% | Loss: 0.1716

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import random

# Dataset path again
data_dir = "/kaggle/input/fruit-and-vegetable-disease-healthy-vs-rotten/Fruit And Vegetable Diseases Dataset"

# Get all class directories (like Apple_Healthy, Banana_Rotten, etc.)
all_classes = os.listdir(data_dir)
all_classes = [cls for cls in all_classes if os.path.isdir(os.path.join(data_dir, cls))]

# Randomly select 10 images from the entire dataset
num_images = 10
selected_images = []

for _ in range(num_images):
    class_name = random.choice(all_classes)
    class_path = os.path.join(data_dir, class_name)
    image_name = random.choice(os.listdir(class_path))
    image_path = os.path.join(class_path, image_name)
    selected_images.append((image_path, class_name))

# Display predictions
plt.figure(figsize=(20, 10))

for idx, (img_path, true_label) in enumerate(selected_images):
    # Load and preprocess image
    img = image.load_img(img_path, target_size=(img_height, img_width))
    img_array = image.img_to_array(img) / 255.0
    img_array_expanded = np.expand_dims(img_array, axis=0)

    # Predict
    prediction = model.predict(img_array_expanded)
    predicted_label = list(train_gen.class_indices.keys())[np.argmax(prediction)]

    # Choose color
    color = 'green' if predicted_label == true_label else 'red'

    # Show image
    plt.subplot(2, 5, idx + 1)
    plt.imshow(img_array)
    plt.axis('off')
    plt.title(f"True: {true_label}\nPred: {predicted_label}", color=color)

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
model.save('/kaggle/working/fruit_model.h5')
# !zip -r /kaggle/working/fruit_model.zip /kaggle/working/fruit_model.h5
# Out:
#   adding: kaggle/working/fruit_model.h5 (deflated 10%)
